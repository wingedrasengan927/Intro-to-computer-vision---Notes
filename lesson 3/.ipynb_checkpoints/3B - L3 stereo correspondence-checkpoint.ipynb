# %% [markdown]
# ## 3B - L3 stereo correspondence

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from scipy.signal import correlate

# %% [markdown]
# #### Load the images

# %%
left = Image.open("data/flowers-left.png")
right = Image.open("data/flowers-right.png")

# %%
# print their sizes
left.size, right.size
# Out:
# ((1920, 1080), (1920, 1080))

# %%
# convert the images to grayscale 
left = left.convert("L")
right = right.convert("L")

# convert images to a numpy array and normalize them
left_arr = np.array(left, dtype=np.float32) / 255.0
right_arr = np.array(right, dtype=np.float32) / 255.0

# %%
# crop the images to remove the white border
bx = 200# approx border width x
by = 20# approx border width y
h, w = left_arr.shape
left_arr = left_arr[by:w-by, bx:w-bx]
right_arr = right_arr[by:w-by, bx:w-bx]

# %%
left_arr.shape, right_arr.shape
# Out:
# ((1060, 1520), (1060, 1520))

# %% [markdown]
# #### resscale the img

# %%
from skimage.transform import rescale

# image is too large, let's rescale it
left_img = rescale(left_arr, 0.25, anti_aliasing=False)
right_img = rescale(right_arr, 0.25, anti_aliasing=False)

# %%
left_img.shape, right_img.shape
# Out:
# ((265, 380), (265, 380))

# %% [markdown]
# #### plot the reference point in the left view

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))

ref_point = np.array([160, 430])

ax.imshow(left_arr, cmap="gray")
ax.scatter(*ref_point, color="red")

# %% [markdown]
# #### Padding the image

# %%
def pad_image(img, size):
    '''
    pads an image with white pixels on all sides with the given size
    '''
    h, w = img.shape
    padded_img = np.ones((h + 2 * size, w + 2 * size)) # 2x because we're padding both sides
    left_corner = np.array([size, size]) # top left corner of the img
    right_corner = np.array([h + size, w + size]) # top right corner of the img
    
    # fill the padded img
    padded_img[left_corner[0]:right_corner[0], left_corner[1]:right_corner[1]] = img
    
    return padded_img

# %%
padded_img = pad_image(left_img, 20)

# %%
plt.imshow(padded_img, cmap="gray")

# %% [markdown]
# #### find the correspondence of the reference point in the right view

# %%
def compute_stereo_correspondence(left, right, ref_point, window_size):
    '''
    find the correspondence point in the right view. It assumes the epipolar lines are
    parallel, horizontal, and are at the same height.
        
    Parameters
    ----------
    left: np.ndarray, shape: (h, w) 
        grayscale normalized version of the left view
    right: np.ndarray, shape: (h, w) 
        grayscale normalized version of the right view.
        It has the same shape as the left view.
    ref_point: np.ndarray
        The reference pixel in the left view.
    window_size: int
        the size of the side of the square window
        
    Returns
    --------
    scores: list
        a list containing the scores at each position along the epipolar line in the right view
    c_point: np.ndarray
        the correspondence point computed based on the best score
    '''
    
    # check if both the views have the same shape
    assert left.shape == right.shape
    
    h, w = left.shape
    x, y = ref_point
    b = window_size//2
    
    # check if the reference point is not at the extremes
    assert x - b >= 0
    assert x + b < w
    assert y - b >= 0
    assert y + b < h
    
    # the patch in the left view we want to find the correspondence
    reference_window = left[y - b: y + b, x - b: x + b] # y comes first!
        
    scores = []
    score_max = float("-inf")
    xmin = 0
    for xi in range(b, w-b):
        patch = right[y-b:y+b, xi-b:xi+b]
        score = correlate(reference_window, patch, mode="valid", method="direct").flatten()[0]
        if score > score_max:
            xmin = xi
            score_max = score
        scores.append(score)
    
    c_point = np.array([xmin, y]) # correspondence_point
    
    return scores, c_point

# %%
scores, c_point = compute_stereo_correspondence(left_arr, right_arr, ref_point, 200)

# %%
plt.plot(scores)
plt.ylabel("score")
plt.xlabel("x`")
# Out:
# Text(0.5, 0, 'x`')

# %% [markdown]
# #### plot the correspondence point in the right image

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

ax[0].imshow(left_arr, cmap="gray")
ax[0].scatter(*ref_point, color="red")

ax[1].imshow(right_arr, cmap="gray")
ax[1].scatter(*c_point, color="green")

# %% [markdown]
# great!

# %% [markdown]
# Observation:
# 1. the reference point needs to be chosen very carefully so that it's unique
# 2. The larger the window size, the more accurate is the correspondence. however, it's less precise.
# 3. The higher the image resolution, the higher the accuracy of the algorithm

# %% [markdown]
# #### compute dense correspondence

# %%
from tqdm import tqdm

# %%
def compute_dense_correspondence(left, right, window_size):
    '''
    compute correspondence for each and every point and return the disparity map
    '''
    b = window_size // 2
    h, w = left.shape
        
    # we need to pad the img first to account for the corners
    padded_left = pad_image(left, b)
    padded_right = pad_image(right, b)
    
    disparity_map = np.zeros(shape=padded_left.shape)

    for x in tqdm(range(b, b + w)):
        for y in range(b, b + h):
            
            # get reference patch
            reference_window = left[y - b: y + b, x - b: x + b]
            
            # find the correspondence point
            score_max = float("-inf")
            xmin = 0
            for xi in range(b, w+b):
                patch = right[y-b:y+b, xi-b:xi+b]
                score = correlate(reference_window, patch, mode="valid", method="direct").flatten()[0]
                if score > score_max:
                    xmin = xi
                    score_max = score

            disparity = abs(xmin - x) # compute disparity
            disparity_map[y, x] = disparity

    return disparity_map

# %%
window_size=200

# %%
# GET BACK TO IT
disparity_map = compute_dense_correspondence(left_arr, right_arr, window_size)
# Out:
#   0%|                                                                                         | 0/1520 [09:43<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9b8b30c5f225> in <module>
# ----> 1 disparity_map = compute_dense_correspondence(left_arr, right_arr, window_size)
#
# <ipython-input-18-74de98f15d5d> in compute_dense_correspondence(left, right, window_size)
#      23             for xi in range(b, w+b):
#      24                 patch = right[y-b:y+b, xi-b:xi+b]
# ---> 25                 score = correlate(reference_window, patch, mode="valid", method="direct").flatten()[0]
#      26                 if score > score_max:
#      27                     xmin = xi
#
# KeyboardInterrupt:

# %%
plt.imshow(disparity_map, cmap="gray")
